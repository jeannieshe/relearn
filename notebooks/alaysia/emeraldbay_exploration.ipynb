# %%
import pandas as pd, ast
from collections import defaultdict

dir_path = '/home/alaysia/.cache/huggingface/hub/datasets--tahoebio--EmeraldBay/snapshots/f2a0be6b02f731553657f0115c345b20bb020ede'
summary_stats_df = pd.read_parquet(dir_path + '/metadata/summary_statistics.parquet')
cell_line_md_df = pd.read_parquet(dir_path + '/metadata/cell_line_metadata.parquet')
drug_md_df = pd.read_parquet(dir_path + '/metadata/drug_metadata.parquet')
gene_md_df = pd.read_parquet(dir_path + '/metadata/gene_metadata.parquet')

# %%
summary_stats_df
# Out:
#       cell_line                                          condition  \
# 0     CVCL_0023                           [('DMSO_T0', 0.0, 'uM')]
# 1     CVCL_0218                           [('DMSO_T0', 0.0, 'uM')]
# 2     CVCL_0320                           [('DMSO_T0', 0.0, 'uM')]
# 3     CVCL_0546                           [('DMSO_T0', 0.0, 'uM')]
# 4     CVCL_0332                           [('DMSO_T0', 0.0, 'uM')]
# ...         ...                                                ...
# 4987  CVCL_1547  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 4988  CVCL_1495  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 4989  CVCL_1531  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 4990  CVCL_1517  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 4991  CVCL_1381  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
#
#       growth_rate
# 0       -0.036039
# 1        1.689574
# 2       -1.872728
# 3       -2.123235
# 4        1.247865
# ...           ...
# 4987     0.517212
# 4988    -0.996782
# 4989    -0.584484
# 4990    -0.186512
# 4991     0.549793
#
# [4992 rows x 3 columns]

# %%
cell_line_md_df
# Out:
#     cell_name Cell_ID_DepMap Cell_ID_Cellosaur Organ Driver_Gene_Symbol  \
# 0        A549     ACH-000681         CVCL_0023  Lung             CDKN2A
# 1        A549     ACH-000681         CVCL_0023  Lung             CDKN2B
# 2        A549     ACH-000681         CVCL_0023  Lung               KRAS
# 3        A549     ACH-000681         CVCL_0023  Lung            SMARCA4
# 4        A549     ACH-000681         CVCL_0023  Lung              STK11
# ..        ...            ...               ...   ...                ...
# 482  LOX-IMVI     ACH-000750         CVCL_1381  Skin             ARID1A
# 483  LOX-IMVI     ACH-000750         CVCL_1381  Skin               BRAF
# 484  LOX-IMVI     ACH-000750         CVCL_1381  Skin             CDKN2A
# 485  LOX-IMVI     ACH-000750         CVCL_1381  Skin                NF1
# 486  LOX-IMVI     ACH-000750         CVCL_1381  Skin               TERT
#
#     Driver_VarZyg Driver_VarType Driver_ProtEffect_or_CdnaEffect  \
# 0             Hom       Deletion                             DEL
# 1             Hom       Deletion                             DEL
# 2             Hom       Missense                          p.G12S
# 3             Hom     Frameshift                        p.Q729fs
# 4             Hom       Stopgain                          p.Q37*
# ..            ...            ...                             ...
# 482           Het       Stopgain                        p.Q1212*
# 483           Het       Missense                         p.V600E
# 484           Hom       Deletion                             DEL
# 485           Het       Stopgain                        p.Q1174*
# 486           NaN       Promoter                        1-124C>T
#
#     Driver_Mech_InferDM Driver_GeneType_DM
# 0                   LoF         Suppressor
# 1                   LoF         Suppressor
# 2                   GoF           Oncogene
# 3                   LoF         Suppressor
# 4                   LoF         Suppressor
# ..                  ...                ...
# 482                 LoF         Suppressor
# 483                 GoF           Oncogene
# 484                 LoF         Suppressor
# 485                 LoF         Suppressor
# 486                 GoF           Oncogene
#
# [487 rows x 10 columns]

# %%
drug_md_df
# Out:
#                     drug                                     targets  \
# 0              Adagrasib                                        KRAS
# 1           Capecitabine                                        TYMP
# 2              Cetuximab                                        EGFR
# 3             Dabrafenib                                  BRAF, RAF1
# 4            Encorafenib                                        BRAF
# 5           Fluorouracil                                        TYMS
# 6               GDC-6036                                        KRAS
# 7           Galunisertib                                      TGFBR1
# 8            Gemcitabine                                        none
# 9             Irinotecan                                        TOP1
# 10             LY3200882                                      TGFBR1
# 11  Lapatinib ditosylate                                 EGFR, ERBB2
# 12            Leucovorin                                        none
# 13           Oxaliplatin                                        none
# 14           PF-06952229                                      TGFBR1
# 15            Paclitaxel                                       TUBB1
# 16           Panitumumab                                        EGFR
# 17            Pertuzumab                                       ERBB2
# 18              RMC-6236                            HRAS, KRAS, NRAS
# 19           Regorafenib  KDR,KIT,PDGFRB,RET,FLT1,FLT4,RAF1,BRAF,TEK
# 20             Sotorasib                                        KRAS
# 21             Tipiracil                                   TYMP,TYMS
# 22            Trametinib                              MAP2K1, MAP2K2
# 23           Trastuzumab                                       ERBB2
# 24          Trifluridine                                        TYMS
# 25             Tucatinib                                       ERBB2
# 26          Vociprotafib                                      PTPN11
#
#     mutations             moa-broad                        moa-fine human-use  \
# 0    KRASG12C  inhibitor/antagonist                   RAS inhibitor       yes
# 1         NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 2         NaN  inhibitor/antagonist             EGFR/ERBB inhibitor       yes
# 3   BRAFV600E  inhibitor/antagonist                   RAF inhibitor       yes
# 4   BRAFV600E  inhibitor/antagonist                   RAF inhibitor       yes
# 5         NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 6    KRASG12C  inhibitor/antagonist                   RAS inhibitor        no
# 7         NaN  inhibitor/antagonist              Other TK inhibitor        no
# 8         NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 9         NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 10        NaN  inhibitor/antagonist              Other TK inhibitor        no
# 11        NaN  inhibitor/antagonist             EGFR/ERBB inhibitor       yes
# 12        NaN               unclear  DNA synthesis/repair inhibitor       yes
# 13        NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 14        NaN  inhibitor/antagonist              Other TK inhibitor        no
# 15        NaN               unclear           Microtubule inhibitor       yes
# 16        NaN  inhibitor/antagonist             EGFR/ERBB inhibitor       yes
# 17        NaN  inhibitor/antagonist             EGFR/ERBB inhibitor       yes
# 18   KRASG12D  inhibitor/antagonist                   RAS inhibitor        no
# 19  BRAFV600E  inhibitor/antagonist              Multi-TK inhibitor       yes
# 20   KRASG12C  inhibitor/antagonist                   RAS inhibitor       yes
# 21        NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 22        NaN  inhibitor/antagonist                   MEK inhibitor       yes
# 23        NaN  inhibitor/antagonist             EGFR/ERBB inhibitor       yes
# 24        NaN  inhibitor/antagonist  DNA synthesis/repair inhibitor       yes
# 25        NaN  inhibitor/antagonist             EGFR/ERBB inhibitor       yes
# 26        NaN  inhibitor/antagonist            Other MAPK inhibitor        no
#
#    clinical-trials                              claude-notes-approval  \
# 0              yes  Adagrasib (Krazati), a KRAS G12C inhibitor, ga...
# 1              yes  Approved oral chemo (Xeloda), first FDA-approv...
# 2              yes  Anti-EGFR monoclonal antibody (Erbitux), FDA a...
# 3              yes  BRAF kinase inhibitor (Tafinlar); FDA-approved...
# 4              yes  BRAF inhibitor (Braftovi); FDA-approved June 2...
# 5              yes  FDA-approved antimetabolite chemotherapy (5-FU...
# 6              yes  GDC-6036 (divarasib), Genentech/Roche covalent...
# 7              yes  TGF-β receptor I inhibitor (LY2157299). Invest...
# 8              yes  Chemotherapy (Gemzar); FDA-approved 1996 pancr...
# 9              yes  Topoisomerase I inhibitor; FDA accelerated app...
# 10             yes  Eli Lilly investigational TGFβ receptor 1 inhi...
# 11             yes  FDA-approved 2007 as Tykerb/Tyverb (lapatinib ...
# 12             yes  Folinic acid; long FDA-approved for methotrexa...
# 13             yes  FDA-approved platinum chemotherapy (Eloxatin),...
# 14             yes  Pfizer TGF-β-R1 inhibitor (MDV6058). Phase I i...
# 15             yes  FDA-approved 1992 (Taxol); taxane chemotherapy...
# 16             yes  Fully human anti-EGFR monoclonal antibody (Vec...
# 17             yes  HER2-targeted monoclonal antibody (Perjeta), F...
# 18             yes  Daraxonrasib, investigational oral RAS(ON) mul...
# 19             yes  FDA-approved (Stivarga, Bayer) 2012 for colore...
# 20             yes  KRAS G12C inhibitor (Lumakras/Amgen). FDA acce...
# 21             yes  Approved 2015 (FDA) only as combination Lonsur...
# 22             yes  FDA-approved MEK1/2 inhibitor (Mekinist, 2013)...
# 23             yes  Humanized anti-HER2 monoclonal antibody (Herce...
# 24             yes  FDA-approved antiviral (ophthalmic Viroptic, 1...
# 25             yes  FDA-approved kinase inhibitor (HER2); approved...
# 26             yes  Investigational SHP2 inhibitor (Revolution Med...
#
#     pubchem-cid                                   canonical-smiles
# 0   138611145.0  CN1CCCC1COC2=NC3=C(CCN(C3)C4=CC=CC5=C4C(=CC=C5...
# 1       60953.0      CCCCCOC(=O)NC1=NC(=O)N(C=C1F)C2C(C(C(O2)C)O)O
# 2           NaN                                                NaN
# 3    44462760.0  CC(C)(C)C1=NC(=C(S1)C2=NC(=NC=C2)N)C3=C(C(=CC=...
# 4    50922675.0  CC(C)N1C=C(C(=N1)C2=C(C(=CC(=C2)Cl)NS(=O)(=O)C...
# 5        3385.0                               C1=C(C(=O)NC(=O)N1)F
# 6   146624881.0  CC1CN(CCN1C2=NC(=NC3=C(C(=C(C=C32)Cl)C4=C(C(=C...
# 7    10090485.0  CC1=NC(=CC=C1)C2=NN3CCCC3=C2C4=C5C=C(C=CC5=NC=...
# 8       60750.0              C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)(F)F
# 9       60838.0  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...
# 10  121249291.0  CC(C)(C1=NC=CC(=C1)NC2=NC=CC(=C2)OC3=CN(N=C3C4...
# 11   11557040.0  CC1=CC=C(C=C1)S(=O)(=O)O.CC1=CC=C(C=C1)S(=O)(=...
# 12  135403648.0  C1C(N(C2=C(N1)N=C(NC2=O)N)C=O)CNC3=CC=C(C=C3)C...
# 13    9887053.0       C1CCC(C(C1)[NH-])[NH-].C(=O)(C(=O)O)O.[Pt+2]
# 14  118211239.0  CC(C)C1=CN=C(C=C1NC2=C(C=NC=C2)C(=O)NC(CO)CO)C...
# 15      36314.0  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...
# 16          NaN                                                NaN
# 17          NaN                                                NaN
# 18  164726578.0  CCN1C2=C3C=C(C=C2)C4=CSC(=N4)CC(C(=O)N5CCCC(N5...
# 19   11167602.0  CNC(=O)C1=NC=CC(=C1)OC2=CC(=C(C=C2)NC(=O)NC3=C...
# 20  137278711.0  CC1CN(CCN1C2=NC(=O)N(C3=NC(=C(C=C32)F)C4=C(C=C...
# 21    6323266.0                C1CC(=N)N(C1)CC2=C(C(=O)NC(=O)N2)Cl
# 22   11707110.0  CC1=C2C(=C(N(C1=O)C)NC3=C(C=C(C=C3)I)F)C(=O)N(...
# 23          NaN                                                NaN
# 24       6256.0            C1C(C(OC1N2C=C(C(=O)NC2=O)C(F)(F)F)CO)O
# 25   51039094.0  CC1=C(C=CC(=C1)NC2=NC=NC3=C2C=C(C=C3)NC4=NC(CO...
# 26  134182831.0  CC1C(C2(CCN(CC2)C3=NC(=C(N=C3CO)SC4=C(C(=NC=C4...

# %%
gene_md_df
# Out:
#       gene_symbol       ensembl_id  token_id
# 0          TSPAN6  ENSG00000000003         3
# 1            TNMD  ENSG00000000005         4
# 2            DPM1  ENSG00000000419         5
# 3           SCYL3  ENSG00000000457         6
# 4        C1orf112  ENSG00000000460         7
# ...           ...              ...       ...
# 63279  AC012476.1  ENSG00000285396     63282
# 63280  AC104162.2  ENSG00000285399     63283
# 63281      SOD2-1  ENSG00000285441     63284
# 63282    ZNF883-1  ENSG00000285447     63285
# 63283  AC139491.7  ENSG00000285476     63286
#
# [63284 rows x 3 columns]
