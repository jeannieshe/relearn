# %% [markdown]
# # This notebook covers how to use the SE model to generate State embeddings for cells in a user-provided AnnData.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The State Embedding model can be used to obtain dense vector representations of single cells. These can then be used by the State Transition model to learn perturbational effects, or for other tasks such as cell type annotation, batch effect correction etc.

# %% [markdown]
# # Installations

# %%
! pip -q install matplotlib-inline scanpy
! pip -q install -U "huggingface_hub>=0.22.0"

import scanpy as sc
import anndata as ad
import matplotlib.pyplot as plt
import numpy as np
import os, sys

if 'MPLBACKEND' in os.environ:
    del os.environ['MPLBACKEND']

# %% [markdown]
# # Download the model folder, including checkpoints, from HuggingFace

# %%
from huggingface_hub import snapshot_download

repo_id = "arcinstitute/SE-600M"
target_dir = "SE-600M"
exclude = ["se600m_epoch4.ckpt", "se600m_epoch4.safetensors"]

if os.path.exists(target_dir) and os.listdir(target_dir):
    raise SystemExit(f"'{target_dir}' already exists and is not empty.")

snapshot_download(
    repo_id=repo_id,
    repo_type="model",
    revision="main",
    local_dir=target_dir,
    local_dir_use_symlinks=False,  # copy files instead of symlinking from cache
    ignore_patterns=exclude,       # skip the big epoch-4 files
    resume_download=True,
)

print(f"Downloaded to ./{target_dir} (excluded: {', '.join(exclude)})")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 'SE-600M' already exists and is not empty.
# /home/jeannie/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Download some tissue data from Tabula Sapiens

# %%
# Download tabula sapiens data

! wget https://datasets.cellxgene.cziscience.com/762edb8f-1207-4814-831e-99d7a801fdec.h5ad -O heart.h5ad
! wget https://datasets.cellxgene.cziscience.com/01e3402f-a625-4c4d-b94a-bc5996f738f7.h5ad -O kidney.h5ad
! wget https://datasets.cellxgene.cziscience.com/d6761a21-e226-434f-9370-fbcc7e549aa0.h5ad -O lung.h5ad
# Out:
# --2025-08-11 17:03:48--  https://datasets.cellxgene.cziscience.com/762edb8f-1207-4814-831e-99d7a801fdec.h5ad
# Resolving datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)... 3.170.229.116, 3.170.229.51, 3.170.229.26, ...
# Connecting to datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)|3.170.229.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1168741941 (1.1G) [binary/octet-stream]
# Saving to: ‘heart.h5ad’
#
# heart.h5ad          100%[===================>]   1.09G   361MB/s    in 3.1s
#
# 2025-08-11 17:03:51 (361 MB/s) - ‘heart.h5ad’ saved [1168741941/1168741941]
#
# --2025-08-11 17:03:51--  https://datasets.cellxgene.cziscience.com/d6761a21-e226-434f-9370-fbcc7e549aa0.h5ad
# Resolving datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)... 3.170.229.116, 3.170.229.51, 3.170.229.26, ...
# Connecting to datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)|3.170.229.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3206851888 (3.0G) [binary/octet-stream]
# Saving to: ‘lung.h5ad’
#
# lung.h5ad           100%[===================>]   2.99G   124MB/s    in 9.9s
#
# 2025-08-11 17:04:01 (310 MB/s) - ‘lung.h5ad’ saved [3206851888/3206851888]

# %%
# Read the h5ad files
heart_adata = ad.read_h5ad("heart.h5ad")
kidney_adata = ad.read_h5ad("kidney.h5ad")
lung_adata = ad.read_h5ad("lung.h5ad")

# Concatenate the AnnData objects
concatenated_adata = ad.concat([heart_adata, kidney_adata, lung_adata], merge="unique")

# Write the concatenated AnnData object to a new h5ad file
concatenated_adata.write("processed.h5ad")

print("Concatenated data saved to processed.h5ad")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Read the h5ad files
#       2 heart_adata = ad.read_h5ad("heart.h5ad")
# ----> 3 kidney_adata = ad.read_h5ad("kidney.h5ad")
#       4 lung_adata = ad.read_h5ad("lung.h5ad")
#       5
#       6 # Concatenate the AnnData objects
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/h5ad.py:285, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     282         return read_dataframe(elem)
#     283     return read_func(elem)
# --> 285 adata = read_dispatched(f, callback=callback)
#     287 # Backwards compat (should figure out which version)
#     288 if "raw.X" in f:
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/experimental/_dispatch_io.py:39, in read_dispatched(elem, callback)
#      35 from anndata._io.specs import _REGISTRY, Reader
#      37 reader = Reader(_REGISTRY, callback=callback)
# ---> 39 return reader.read_elem(elem)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/utils.py:234, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     232     raise ValueError(msg)
#     233 try:
# --> 234     return func(*args, **kwargs)
#     235 except Exception as e:
#     236     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/specs/registry.py:287, in Reader.read_elem(self, elem, modifiers)
#     285 if self.callback is None:
#     286     return read_func(elem)
# --> 287 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/h5ad.py:270, in read_h5ad.<locals>.callback(read_func, elem_name, elem, iospec)
#     265 def callback(read_func, elem_name: str, elem: StorageType, iospec: IOSpec):
#     266     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     267         return AnnData(**{
#     268             # This is covering up backwards compat in the anndata initializer
#     269             # In most cases we should be able to call `func(elen[k])` instead
# --> 270             k: read_dispatched(elem[k], callback)
#     271             for k in elem
#     272             if not k.startswith("raw.")
#     273         })
#     274     elif elem_name.startswith("/raw."):
#     275         return None
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/experimental/_dispatch_io.py:39, in read_dispatched(elem, callback)
#      35 from anndata._io.specs import _REGISTRY, Reader
#      37 reader = Reader(_REGISTRY, callback=callback)
# ---> 39 return reader.read_elem(elem)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/utils.py:234, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     232     raise ValueError(msg)
#     233 try:
# --> 234     return func(*args, **kwargs)
#     235 except Exception as e:
#     236     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/specs/registry.py:287, in Reader.read_elem(self, elem, modifiers)
#     285 if self.callback is None:
#     286     return read_func(elem)
# --> 287 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/h5ad.py:283, in read_h5ad.<locals>.callback(read_func, elem_name, elem, iospec)
#     280 elif elem_name in {"/obs", "/var"}:
#     281     # Backwards compat
#     282     return read_dataframe(elem)
# --> 283 return read_func(elem)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/specs/methods.py:453, in read_mapping(elem, _reader)
#     450 @_REGISTRY.register_read(H5Group, IOSpec("dict", "0.1.0"))
#     451 @_REGISTRY.register_read(ZarrGroup, IOSpec("dict", "0.1.0"))
#     452 def read_mapping(elem: GroupStorageType, *, _reader: Reader) -> dict[str, AxisStorable]:
# --> 453     return {k: _reader.read_elem(v) for k, v in dict(elem).items()}
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/utils.py:234, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     232     raise ValueError(msg)
#     233 try:
# --> 234     return func(*args, **kwargs)
#     235 except Exception as e:
#     236     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/specs/registry.py:287, in Reader.read_elem(self, elem, modifiers)
#     285 if self.callback is None:
#     286     return read_func(elem)
# --> 287 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/h5ad.py:283, in read_h5ad.<locals>.callback(read_func, elem_name, elem, iospec)
#     280 elif elem_name in {"/obs", "/var"}:
#     281     # Backwards compat
#     282     return read_dataframe(elem)
# --> 283 return read_func(elem)
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_io/specs/methods.py:989, in read_sparse(elem, _reader)
#     984 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     985 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     986 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#     987 @_REGISTRY.register_read(ZarrGroup, IOSpec("csr_matrix", "0.1.0"))
#     988 def read_sparse(elem: GroupStorageType, *, _reader: Reader) -> CSMatrix | CSArray:
# --> 989     return sparse_dataset(elem).to_memory()
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/anndata/_core/sparse_dataset.py:664, in BaseCompressedSparseDataset.to_memory(self)
#     660 format_class = get_memory_class(
#     661     self.format, use_sparray_in_io=settings.use_sparse_array_on_read
#     662 )
#     663 mtx = format_class(self.shape, dtype=self.dtype)
# --> 664 mtx.data = self._data[...]
#     665 mtx.indices = self._indices[...]
#     666 mtx.indptr = self._indptr
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
# ---> 54 'Could not get source, probably due dynamically evaluated source code.'
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
# ---> 55 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/h5py/_hl/dataset.py:872, in Dataset.__getitem__(self, args, new_dtype)
#     870 if self._fast_read_ok and (new_dtype is None):
#     871     try:
# --> 872         return self._fast_reader.read(args)
#     873     except TypeError:
#     874         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %% [markdown]
# # Compute the embedding using SE-600M

# %%
import time
start = time.time()

# Embed the data (adds a .obsm['X_state'] property)
! state emb transform \
    --model-folder SE-600M \
    --input processed.h5ad \
    --output processed_emb.h5ad

elapsed = time.time() - start
print(f"Inference time: {elapsed:.1f}s")
# Alternative ways to run the model:

# Install the package:
# ! uv tool install arc-state
# ! state emb transform ...
# Out:
# INFO:state._cli._emb._transform:Using model checkpoint: SE-600M/se600m_epoch16.ckpt
# INFO:state._cli._emb._transform:Creating inference object
# INFO:state._cli._emb._transform:Found protein embeddings in model folder: SE-600M/protein_embeddings.pt. Using these and overriding config.
# INFO:state._cli._emb._transform:Loading model from checkpoint: SE-600M/se600m_epoch16.ckpt
# Traceback (most recent call last):
#   File "/home/jeannie/miniconda/envs/pytorch-pip/bin/state", line 6, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/jeannie/state/src/state/__main__.py", line 103, in main
#     run_emb_transform(args)
#   File "/home/jeannie/state/src/state/_cli/_emb/_transform.py", line 140, in run_emb_transform
#     inferer.load_model(args.checkpoint)
#   File "/home/jeannie/state/src/state/emb/inference.py", line 103, in load_model
#     ckpt = torch.load(checkpoint, map_location="cpu", weights_only=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jeannie/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/torch/serialization.py", line 1525, in load
#     return _load(
#            ^^^^^^
#   File "/home/jeannie/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/torch/serialization.py", line 2114, in _load
#     result = unpickler.load()
#              ^^^^^^^^^^^^^^^^
#   File "/home/jeannie/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/torch/serialization.py", line 2078, in persistent_load
#     typed_storage = load_tensor(
#                     ^^^^^^^^^^^^
#   File "/home/jeannie/miniconda/envs/pytorch-pip/lib/python3.12/site-packages/torch/serialization.py", line 2031, in load_tensor
#     zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)
# KeyboardInterrupt
# ^C
# Inference time: 18.2s

# %% [markdown]
# # Compute PCA and plot data using gene expression, vs using the State Embeddings

# %%
# Create AnnData object for X_state and compute PCA

adata = sc.read("processed_emb.h5ad")

# Compute PCA on the gene expression data
sc.tl.pca(adata)

# Create figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot 1: PCA using .X
sc.pl.pca(adata,
          color='donor_id',
          components=['1,2'],
          ax=axes[0],
          show=False,
          title="PCA Separation of Donor using .X")

# Plot 2: PCA using .obsm['X_state']
sc.pl.pca(adata,
          color='tissue_in_publication',
          components=['1,2'],
          ax=axes[1],
          show=False,
          title="PCA Separation of Tissue using .X")

# Adjust layout and show
plt.tight_layout()
plt.show()

# %%
# Create AnnData object for X_state and compute PCA
adata_state = ad.AnnData(adata.obsm['X_state'])
adata_state.obs_names = adata.obs_names
adata_state.obs['tissue_in_publication'] = adata.obs['tissue_in_publication']
adata_state.obs['donor_id'] = adata.obs['donor_id']
sc.tl.pca(adata_state)

# Create figure with subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot 1: PCA using .X
sc.pl.pca(adata_state,
          color='donor_id',
          components=['1,2'],
          ax=axes[0],
          show=False,
          title="PCA Separation of Donor using .obsm['X_state']")

# Plot 2: PCA using .obsm['X_state']
sc.pl.pca(adata_state,
          color='tissue_in_publication',
          components=['1,2'],
          ax=axes[1],
          show=False,
          title="PCA Separation of Tissue using .obsm['X_state']")

# Adjust layout and show
plt.tight_layout()
plt.show()
